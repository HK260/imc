# %%
import pandas as pd

# %%
data0 = pd.read_csv('C:/Users/ASUS/Desktop/IMC/IMC main/data/round0-day1.csv', sep=';')

# %%
data1 = pd.read_csv('C:/Users/ASUS/Desktop/IMC/IMC main/data/prices_round_1_day_-1.csv', sep=';')
data2 = pd.read_csv('C:/Users/ASUS/Desktop/IMC/IMC main/data/prices_round_1_day_-2.csv', sep=';')

# %%
data_pearls1 = data0[data0['product'] == 'PEARLS']
data_pearls2=data1[data1['product'] == 'PEARLS']

# %%
data_pearls3=data2[data2['product'] == 'PEARLS']

# %%
data_pearls1
# Out:
#        day  timestamp product  bid_price_1  bid_volume_1  bid_price_2  \
# 0        0          0  PEARLS         9998             1       9995.0
# 2        0        100  PEARLS         9996             1       9995.0
# 4        0        200  PEARLS         9996             1       9995.0
# 6        0        300  PEARLS         9996             2       9995.0
# 8        0        400  PEARLS         9998             5       9996.0
# ...    ...        ...     ...          ...           ...          ...
# 19990    0     999500  PEARLS         9995            28          NaN
# 19992    0     999600  PEARLS         9996             2       9995.0
# 19994    0     999700  PEARLS         9996             2       9995.0
# 19996    0     999800  PEARLS         9995            27          NaN
# 19998    0     999900  PEARLS         9996             2       9995.0
#
#        bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# ...

# %%
data_pearls2
# Out:
#        day  timestamp product  bid_price_1  bid_volume_1  bid_price_2  \
# 0       -1          0  PEARLS        10002             1       9996.0
# 2       -1        100  PEARLS         9996             2       9995.0
# 5       -1        200  PEARLS         9995            20          NaN
# 6       -1        300  PEARLS         9996             2       9995.0
# 8       -1        400  PEARLS         9996             2       9995.0
# ...    ...        ...     ...          ...           ...          ...
# 19991   -1     999500  PEARLS        10000             5       9996.0
# 19992   -1     999600  PEARLS        10000             4       9996.0
# 19995   -1     999700  PEARLS         9995            26          NaN
# 19997   -1     999800  PEARLS         9995            20          NaN
# 19999   -1     999900  PEARLS         9996             2       9995.0
#
#        bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# ...

# %%
data_pearls3
# Out:
#        day  timestamp product  bid_price_1  bid_volume_1  bid_price_2  \
# 1       -2          0  PEARLS         9996             1       9995.0
# 3       -2        100  PEARLS        10000             5       9995.0
# 4       -2        200  PEARLS         9996             1       9995.0
# 6       -2        300  PEARLS         9996             1       9995.0
# 8       -2        400  PEARLS         9995            20          NaN
# ...    ...        ...     ...          ...           ...          ...
# 19991   -2     999500  PEARLS         9996             2       9995.0
# 19993   -2     999600  PEARLS         9998             6       9995.0
# 19995   -2     999700  PEARLS         9995            22          NaN
# 19997   -2     999800  PEARLS         9996             1       9995.0
# 19998   -2     999900  PEARLS         9996             2       9995.0
#
#        bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# ...

# %%
data_pearls1['mid_price'].plot()
# Out:
# <Axes: >

# %%
data_pearls2['mid_price'].plot()
# Out:
# <Axes: >

# %%
data_pearls3['mid_price'].plot()
# Out:
# <Axes: >
